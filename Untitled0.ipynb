# %% [markdown]
# <a href="https://colab.research.google.com/github/ytyc2k/APPS/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from google.colab import files
#uploaded = files.upload()

#!git clone https://github.com/koreal6803/Stocker.git
#!pip install -r Stocker/requirements.txt
#! pip install tushare

import tushare
HisPrice=tushare.get_hist_data('600460')
HisPrice.to_csv('price.csv')

import warnings
warnings.filterwarnings('ignore')



import pandas as pd
### 讀入series
# df = pd.read_csv('price.csv')
df = pd.read_csv('price.csv',usecols=[0,3],index_col='date', parse_dates=['date'])
price = df.squeeze()

from Stocker.stocker import Stocker
tsmc = Stocker(price)
model, model_data = tsmc.create_prophet_model(days=90)
tsmc.evaluate_prediction()
tsmc.changepoint_prior_analysis(changepoint_priors=[0.001, 0.05, 0.1, 0.2])
# Out:
# the stock Stocker Initialized. Data covers 2016-09-14 00:00:00 to 2019-03-15 00:00:00.
# Predicted Price on 2019-06-13 00:00:00 = $8.66
# Prediction Range: 2018-03-15 00:00:00 to 2019-03-15 00:00:00.
#
# Predicted price on 2019-03-14 00:00:00 = $28.32.
# Actual price on    2019-03-14 00:00:00 = $16.27.
#
# Average Absolute Error on Training Data = $0.42.
# Average Absolute Error on Testing  Data = $9.24.
#
# When the model predicted an increase, the price increased 61.11% of the time.
# When the model predicted a  decrease, the price decreased  48.03% of the time.
#
# The actual value was within the 80% confidence interval 17.28% of the time.

# %% [markdown]
# # New Section
